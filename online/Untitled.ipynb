# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tsfresh as tsf
import seaborn as sns

# %%
trai = pd.read_csv('data/train.csv', parse_dates=['DATE'])

ho_IDs = np.random.choice( trai.ATM_ID.unique(), 50, replace=False)

ho_set = trai[trai.ATM_ID.isin(ho_IDs)]
ho_set.to_csv

# %%
data = pd.read_csv('./data/train.csv', parse_dates=['DATE'])

# %%
data.head()
# Out:
#         DATE  ATM_ID  CLIENT_OUT
# 0 2015-01-01       0       91600
# 1 2015-01-02       0      136500
# 2 2015-01-03       0      335400
# 3 2015-01-04       0      379000
# 4 2015-01-05       0      344100

# %%
ATM_IDs = data.ATM_ID.unique()

# %%
data.shape
# Out:
# (287400, 3)

# %%
data.describe()
# Out:
#              ATM_ID    CLIENT_OUT
# count  287400.00000  2.874000e+05
# mean      203.08000  3.681474e+05
# std       123.98492  4.288130e+05
# min         0.00000 -4.100000e+04
# 25%        88.75000  3.440000e+04
# 50%       206.00000  2.188000e+05
# 75%       309.25000  5.586000e+05
# max       419.00000  5.752900e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287400 entries, 0 to 287399
# Data columns (total 3 columns):
# DATE          287400 non-null datetime64[ns]
# ATM_ID        287400 non-null int64
# CLIENT_OUT    287400 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 6.6 MB

# %%
type(ATM_IDs)
# Out:
# numpy.ndarray

# %%
ATM_IDs[9]
# Out:
# 10

# %%
data[data['ATM_ID'] == ID].iloc[7:].shape
# Out:
# (951, 3)

# %%
data[data['ATM_ID'] == ID].iloc[:-7].shape
# Out:
# (951, 3)

# %%
ID = ATM_IDs[4]
plt.plot(data[data['ATM_ID'] == ID]['CLIENT_OUT'].iloc[7:].as_matrix() - data[data['ATM_ID'] == ID]['CLIENT_OUT'].iloc[:-7].as_matrix())
plt.show()

# %%
data.loc[97800]
# Out:
# DATE          2015-03-26 00:00:00
# ATM_ID                        123
# CLIENT_OUT                 206200
# Name: 97800, dtype: object

# %%
ID = 123#ATM_IDs[i]
(data[data['ATM_ID'] == ID]['CLIENT_OUT']/1e6).plot()
plt.show()

# %%
for i in range(200,201):
    ID = ATM_IDs[i]
    (data[data['ATM_ID'] == ID]['CLIENT_OUT']/1e6).plot()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f4bc57e1f996> in <module>()
#       1 for i in range(200,201):
# ----> 2     ID = ATM_IDs[i]
#       3     (data[data['ATM_ID'] == ID]['CLIENT_OUT']/1e6).plot()
#       4     plt.show()
#
# NameError: name 'ATM_IDs' is not defined

# %%
ruptures-master/setup.py install
# Out:
#   File "<ipython-input-1-e7a3ae0768ab>", line 1
#     ruptures-master/setup.py install
#                                    ^
# SyntaxError: invalid syntax

# %%
true = pd.read_csv('splits/data/y_true_private.csv', parse_dates=["DATE"])

# %%
true[true.ATM_ID==335].set_index('DATE').CLIENT_OUT.plot()

# %%
prv = pd.read_csv('splits/data/train_private.csv', parse_dates=["DATE"])

# %%
plt.figure(figsize=[20,5])
(prv[prv.ATM_ID==335].iloc[-14:].set_index('DATE').CLIENT_OUT/1e6).plot()
